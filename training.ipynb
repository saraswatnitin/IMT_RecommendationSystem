# %%
import pandas as pd
import ast
import matplotlib.pyplot as plt
credits=pd.read_csv("C:/Dev/aiproff_myaipoc/IMT/Recommendation Systems using Python/kaggle/tmdb_5000_credits.csv")
movies=pd.read_csv("C:/Dev/aiproff_myaipoc/IMT/Recommendation Systems using Python/kaggle/tmdb_5000_movies.csv")
movies.shape,credits.shape
# Out:
# ((4803, 20), (4803, 4))

# %%
#Drop these columns 
movies.isnull().sum()
dfm=movies.drop(['homepage','tagline','release_date','runtime','title','status'],axis=1)
dfm=dfm.dropna(axis=0)
dfm.head(3)
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# ...

# %%
#Delete the index of credits & movie file  and merge them
credits = credits.reset_index(drop=True)
dfm = dfm.reset_index(drop=True)
df=dfm.join(credits)
df.head(3)
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# ...

# %%
#Print the different genres 
df['genres'][0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
#Strip off ids and keep the actual values
def prep_dict_ro_list(genres):
    L=[]
    genres=ast.literal_eval(genres)
    for i in genres:
        L.append(i["name"])
    return L

# %%
#Print genres
prep_dict_ro_list(df['genres'][0])
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
df['genres']=df['genres'].apply(prep_dict_ro_list)
df.head(3)
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# ...

# %%
df['keywords']=df['keywords'].apply(prep_dict_ro_list)
df.head(3)
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# ...

# %%
df['cast']=[prep_dict_ro_list(str(ast.literal_eval(k)[0:3])) for k in df['cast']]
df.head(3)
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# ...

# %%
ast.literal_eval(df['crew'][0])[0:3]
# Out:
# [{'credit_id': '52fe48009251416c750aca23',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1721,
#   'job': 'Editor',
#   'name': 'Stephen E. Rivkin'},
#  {'credit_id': '539c47ecc3a36810e3001f87',
#   'department': 'Art',
#   'gender': 2,
#   'id': 496,
#   'job': 'Production Design',
#   'name': 'Rick Carter'},
#  {'credit_id': '54491c89c3a3680fb4001cf7',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 900,
#   'job': 'Sound Designer',
#   'name': 'Christopher Boyes'}]

# %%
#Define functions to capture literal values of director and producer
def director(crew):
    crew_list = ast.literal_eval(crew)
    director = [x['name'] for x in crew_list if x['job'] == 'Director']
    return director
def producer(crew):
    crew_list = ast.literal_eval(crew)
    producers = [x['name'] for x in crew_list if x['job'] == 'Producer'][:3]
    return producers

# def producer(crew):
#     L=[ast.literal_eval(crew).index(x) for x in ast.literal_eval(crew) if  x['job']=='Producer']
#     producer=[]
#     for j in L[0:3]:
#         temp=ast.literal_eval(crew)[j]
#         if(temp['job']=='Producer'):
#             producer.append(temp['name'])
#     return producer

# df['Producer']=df['crew'].apply(producer)           ##################  TAKING LOT OF TIME TO RUN  ######################

# %%
director(df['crew'][1])
# Out:
# ['Gore Verbinski']

# %%
df['Producer']=df['crew'].apply(producer)
df.head(3)
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# ...

# %%
df['Director']=df['crew'].apply(director)
df.head(3)
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# ...

# %%
df1=df.drop(['crew'],axis=1)
df1.head(3)
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# ...

# %%
df1['overview']=df1['overview'].apply(lambda x: x.split(','))
df1.head(3)
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# 2  [spy, based on novel, secret agent, sequel, mi...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  [In the 22nd century,  a paraplegic Marine is ...  150.437577
# 1  [Captain Barbossa,  long believed to be dead, ...  139.082615
# ...

# %%
df2=df1.drop(['production_companies','production_countries','original_language','original_title','spoken_languages'],axis=1)
df2.head(3)
# Out:
#       budget                                         genres      id  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1  300000000                   [Adventure, Fantasy, Action]     285
# 2  245000000                     [Action, Adventure, Crime]  206647
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
#
#                                             overview  popularity     revenue  \
# 0  [In the 22nd century,  a paraplegic Marine is ...  150.437577  2787965087
# 1  [Captain Barbossa,  long believed to be dead, ...  139.082615   961000000
# 2  [A cryptic message from Bond’s past sends him ...  107.376788   880674609
#
#    vote_average  vote_count  movie_id  \
# 0           7.2       11800     19995
# 1           6.9        4500       285
# 2           6.3        4466    206647
#
# ...

# %%
#Normalize the values of continuous variables by subtracting from mean value and dividing by standard deviation 
#This is a good practice when dealing with variables which have diverse range of values
def norm(column):
    ans=column-column.mean()
    ans=ans/column.std()
    return round(ans,2)

# %%
df2['budget']=norm(df2['budget'])
df2['budget']=df2['budget'].apply(lambda x: [x])
df2['popularity']=norm(df2['popularity'])
df2['popularity']=df2['popularity'].apply(lambda x: [x])
df2['revenue']=norm(df2['revenue'])
df2['revenue']=df2['revenue'].apply(lambda x: [x])
df2['vote_average']=norm(df2['vote_average'])
df2['vote_average']=df2['vote_average'].apply(lambda x: [x])
df2['vote_count']=norm(df2['vote_count'])
df2['vote_count']=df2['vote_count'].apply(lambda x: [x])

# %%
df3=df2
df3['genres']=df2['genres'].apply(lambda x:[i.replace(" ","") for i in x])
df3['keywords']=df2['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
df3['cast']=df2['cast'].apply(lambda x:[i.replace(" ","") for i in x])
df3['Producer']=df2['Producer'].apply(lambda x:[i.replace(" ","") for i in x])
df3['Director']=df2['Director'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
df3['tags']=df3['genres']+df3['keywords']+df3['overview']+df3['cast']+df3['Producer']+df3['Director']+df3['budget']+df3['popularity']+df3['revenue']+df3['vote_average']+df3['vote_count']

# %%
df3['tags']=df3['tags'].apply(lambda x: " ".join(map(str, x)))

# %%
df3['tags'][0]
# Out:
# 'Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d In the 22nd century  a paraplegic Marine is dispatched to the moon Pandora on a unique mission  but becomes torn between following orders and protecting an alien civilization. SamWorthington ZoeSaldana SigourneyWeaver JamesCameron JonLandau JamesCameron 5.11 4.05 16.61 0.93 9.0'

# %%
df2.head(3)
# Out:
#    budget                                        genres      id  \
# 0  [5.11]  [Action, Adventure, Fantasy, ScienceFiction]   19995
# 1  [6.65]                  [Adventure, Fantasy, Action]     285
# 2   [5.3]                    [Action, Adventure, Crime]  206647
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
#
#                                             overview popularity  revenue  \
# 0  [In the 22nd century,  a paraplegic Marine is ...     [4.05]  [16.61]
# 1  [Captain Barbossa,  long believed to be dead, ...     [3.69]   [5.39]
# 2  [A cryptic message from Bond’s past sends him ...      [2.7]    [4.9]
#
#   vote_average vote_count  movie_id                                     title  \
# 0       [0.93]      [9.0]     19995                                    Avatar
# ...

# %%
df4=df3.drop(['budget','popularity','revenue','vote_average','vote_count','genres','keywords','overview','movie_id','cast','Producer','Director'],axis=1)

# %%
df4['tags'][0]
# Out:
# 'Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d In the 22nd century  a paraplegic Marine is dispatched to the moon Pandora on a unique mission  but becomes torn between following orders and protecting an alien civilization. SamWorthington ZoeSaldana SigourneyWeaver JamesCameron JonLandau JamesCameron 5.11 4.05 16.61 0.93 9.0'

# %%
df4['tags']=df4['tags'].apply(lambda x: x.lower())

# %%
df4['title']=df4['title'].apply(lambda x: x.lower())
df4.head(3)
# Out:
#        id                                     title  \
# 0   19995                                    avatar
# 1     285  pirates of the caribbean: at world's end
# 2  206647                                   spectre
#
#                                                 tags
# 0  action adventure fantasy sciencefiction cultur...
# 1  adventure fantasy action ocean drugabuse exoti...
# 2  action adventure crime spy basedonnovel secret...

# %%
df4['tags'][0]
# Out:
# 'action adventure fantasy sciencefiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d in the 22nd century  a paraplegic marine is dispatched to the moon pandora on a unique mission  but becomes torn between following orders and protecting an alien civilization. samworthington zoesaldana sigourneyweaver jamescameron jonlandau jamescameron 5.11 4.05 16.61 0.93 9.0'

# %%
from nltk.stem.porter import PorterStemmer      #We use Stemming to get the stem of the word - What is the advantage 
                                                #of this and how is it different from Lemmatization ?
                                                #https://ayselaydin.medium.com/2-stemming-lemmatization-in-nlp-text-preprocessing-techniques-adfe4d84ceee
ps=PorterStemmer()                              ##### convert loved/loving to love ,dancing/dance to danc

# %%
#Create Stem of words 
def stem(text):
    l=[]
    for i in text.split():
        l.append(ps.stem(i))
    l=" ".join(l)
    return l

# %%
df4['tags']=df4['tags'].apply(stem)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
mat=cv.fit_transform(df4['tags']).toarray()

# %%
mat.shape
# Out:
# (4800, 5000)

# %%
cv.get_feature_names_out()
# Out:
# array(['000', '007', '01', ..., 'zone', 'zoo', 'zooeydeschanel'],
#       dtype=object)

# %%
df4['tags'][0]
# Out:
# 'action adventur fantasi sciencefict cultureclash futur spacewar spacecoloni societi spacetravel futurist romanc space alien tribe alienplanet cgi marin soldier battl loveaffair antiwar powerrel mindandsoul 3d in the 22nd centuri a parapleg marin is dispatch to the moon pandora on a uniqu mission but becom torn between follow order and protect an alien civilization. samworthington zoesaldana sigourneyweav jamescameron jonlandau jamescameron 5.11 4.05 16.61 0.93 9.0'

# %%
# finding cosine distance b/w movie vectors
# cosine similarity = 1/(cosine distance) =1/(angle b/w vectors)

# %%
from sklearn.metrics.pairwise  import cosine_similarity

# %%
similarity=cosine_similarity(mat)

# %%
similarity.shape
# Out:
# (4800, 4800)

# %%
similarity[0]
# Out:
# array([1.        , 0.07063224, 0.07537784, ..., 0.03959038, 0.02051525,
#        0.        ])

# %%
sorted(similarity[0],reverse=True)[0:10]  ### index positions lost after sorting
# Out:
# [0.9999999999999998,
#  0.2771609312622936,
#  0.24972268432951006,
#  0.2461829819586655,
#  0.23354968324845687,
#  0.22438727760202976,
#  0.2201927530252721,
#  0.220043114711676,
#  0.21452908258025832,
#  0.21320071635561041]

# %%
### we do mapping here
# sorted(list(enumerate(similarity[0])), reverse=True)[0:10] do sorting by index 0 enumerator


sorted(list(enumerate(similarity[0])), reverse=True, key=lambda x: x[1])[0:10]
# Out:
# [(0, 0.9999999999999998),
#  (2403, 0.2771609312622936),
#  (1213, 0.24972268432951006),
#  (2994, 0.2461829819586655),
#  (582, 0.23354968324845687),
#  (507, 0.22438727760202976),
#  (1191, 0.2201927530252721),
#  (3723, 0.220043114711676),
#  (539, 0.21452908258025832),
#  (1198, 0.21320071635561041)]

# %%
#Define a function to recommend a movie based on the movie selection by the user
def recommend(movie):
    try:
        indx=df4[df4['title']==movie.lower()].index[0]
        movie_list=sorted(list(enumerate(similarity[indx])), reverse=True, key=lambda x: x[1])[1:6]
        for i,_ in movie_list:
            print(df4.iloc[i]['title'])
    except IndexError:
        print('Movie Not Found !!!')

# %%
recommend('Inception')
#output in the form of top 5 recommendations
# Out:
# 12 rounds
# the iceman
# pontypool
# a hard day's night
# ghost dog: the way of the samurai

# %%
import numpy as np
#save the file 
np.save('similarity.npy', similarity)
