# %%
import pandas as pd
import ast
import matplotlib.pyplot as plt
credits=pd.read_csv("/kaggle/input/tmdb-movie-metadata/tmdb_5000_credits.csv")
movies=pd.read_csv("/kaggle/input/tmdb-movie-metadata/tmdb_5000_movies.csv")
movies.shape,credits.shape
# Out:
# ((4803, 20), (4803, 4))

# %%
movies.isnull().sum()
dfm=movies.drop(['homepage','tagline','release_date','runtime','title','status'],axis=1)
dfm=dfm.dropna(axis=0)
dfm
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   72766
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  231617
# 4801          0                                                 []  126186
# 4802          0                [{"id": 99, "name": "Documentary"}]   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4799                                                 []                en
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                 ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]
# 4799                                                 []
# 4800  [{"name": "Front Street Pictures", "id": 3958}...
# 4801                                                 []
# 4802  [{"name": "rusty bear entertainment", "id": 87...
#
#                                    production_countries     revenue  \
# 0     [{"iso_3166_1": "US", "name": "United States o...  2787965087
# 1     [{"iso_3166_1": "US", "name": "United States o...   961000000
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   880674609
# 3     [{"iso_3166_1": "US", "name": "United States o...  1084939099
# 4     [{"iso_3166_1": "US", "name": "United States o...   284139100
# ...                                                 ...         ...
# 4798  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...     2040920
# 4799                                                 []           0
# 4800  [{"iso_3166_1": "US", "name": "United States o...           0
# 4801  [{"iso_3166_1": "US", "name": "United States o...           0
# 4802  [{"iso_3166_1": "US", "name": "United States o...           0
#
#                                        spoken_languages  vote_average  \
# 0     [{"iso_639_1": "en", "name": "English"}, {"iso...           7.2
# 1              [{"iso_639_1": "en", "name": "English"}]           6.9
# 2     [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...           6.3
# 3              [{"iso_639_1": "en", "name": "English"}]           7.6
# 4              [{"iso_639_1": "en", "name": "English"}]           6.1
# ...                                                 ...           ...
# 4798      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]           6.6
# 4799                                                 []           5.9
# 4800           [{"iso_639_1": "en", "name": "English"}]           7.0
# 4801           [{"iso_639_1": "en", "name": "English"}]           5.7
# 4802           [{"iso_639_1": "en", "name": "English"}]           6.3
#
#       vote_count
# 0          11800
# 1           4500
# 2           4466
# 3           9106
# 4           2124
# ...          ...
# 4798         238
# 4799           5
# 4800           6
# 4801           7
# 4802          16
#
# [4800 rows x 14 columns]

# %%
credits = credits.reset_index(drop=True)
dfm = dfm.reset_index(drop=True)
df=dfm.join(credits)
df
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4795     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
# 4796       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   72766
# 4797          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  231617
# 4798          0                                                 []  126186
# 4799          0                [{"id": 99, "name": "Documentary"}]   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4795  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4796                                                 []                en
# 4797  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4798                                                 []                en
# 4799  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4795                               El Mariachi
# 4796                                 Newlyweds
# 4797                 Signed, Sealed, Delivered
# 4798                          Shanghai Calling
# 4799                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4795  El Mariachi just wants to play his guitar and ...   14.269792
# 4796  A newlywed couple's honeymoon is upended by th...    0.642552
# 4797  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4798  When ambitious New York attorney Sam is sent t...    0.857008
# 4799  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                 ...
# 4795           [{"name": "Columbia Pictures", "id": 5}]
# 4796                                                 []
# 4797  [{"name": "Front Street Pictures", "id": 3958}...
# 4798                                                 []
# 4799  [{"name": "rusty bear entertainment", "id": 87...
#
#                                    production_countries     revenue  \
# 0     [{"iso_3166_1": "US", "name": "United States o...  2787965087
# 1     [{"iso_3166_1": "US", "name": "United States o...   961000000
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   880674609
# 3     [{"iso_3166_1": "US", "name": "United States o...  1084939099
# 4     [{"iso_3166_1": "US", "name": "United States o...   284139100
# ...                                                 ...         ...
# 4795  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...     2040920
# 4796                                                 []           0
# 4797  [{"iso_3166_1": "US", "name": "United States o...           0
# 4798  [{"iso_3166_1": "US", "name": "United States o...           0
# 4799  [{"iso_3166_1": "US", "name": "United States o...           0
#
#                                        spoken_languages  vote_average  \
# 0     [{"iso_639_1": "en", "name": "English"}, {"iso...           7.2
# 1              [{"iso_639_1": "en", "name": "English"}]           6.9
# 2     [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...           6.3
# 3              [{"iso_639_1": "en", "name": "English"}]           7.6
# 4              [{"iso_639_1": "en", "name": "English"}]           6.1
# ...                                                 ...           ...
# 4795      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]           6.6
# 4796                                                 []           5.9
# 4797           [{"iso_639_1": "en", "name": "English"}]           7.0
# 4798           [{"iso_639_1": "en", "name": "English"}]           5.7
# 4799           [{"iso_639_1": "en", "name": "English"}]           6.3
#
#       vote_count  movie_id                                     title  \
# 0          11800     19995                                    Avatar
# 1           4500       285  Pirates of the Caribbean: At World's End
# 2           4466    206647                                   Spectre
# 3           9106     49026                     The Dark Knight Rises
# 4           2124     49529                               John Carter
# ...          ...       ...                                       ...
# 4795         238    124606                                      Bang
# 4796           5     14337                                    Primer
# 4797           6     67238                                    Cavite
# 4798           7      9367                               El Mariachi
# 4799          16     72766                                 Newlyweds
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                 ...
# 4795  [{"cast_id": 2, "character": "The Girl", "cred...
# 4796  [{"cast_id": 1, "character": "Aaron", "credit_...
# 4797                                                 []
# 4798  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4799  [{"cast_id": 1, "character": "Buzzy", "credit_...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4795  [{"credit_id": "52fe4ab0c3a368484e161add", "de...
# 4796  [{"credit_id": "52fe45e79251416c75066791", "de...
# 4797  [{"credit_id": "52fe475dc3a368484e0c319f", "de...
# 4798  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4799  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
#
# [4800 rows x 18 columns]

# %%
df['genres'][0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
def prep_dict_ro_list(genres):
    L=[]
    genres=ast.literal_eval(genres)
    for i in genres:
        L.append(i["name"])
    return L

# %%
prep_dict_ro_list(df['genres'][0])
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
df['genres']=df['genres'].apply(prep_dict_ro_list)

# %%
df['keywords']=df['keywords'].apply(prep_dict_ro_list)

# %%
df['cast']=[prep_dict_ro_list(str(ast.literal_eval(k)[0:3])) for k in df['cast']]

# %%
ast.literal_eval(df['crew'][0])[0:3]
# Out:
# [{'credit_id': '52fe48009251416c750aca23',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1721,
#   'job': 'Editor',
#   'name': 'Stephen E. Rivkin'},
#  {'credit_id': '539c47ecc3a36810e3001f87',
#   'department': 'Art',
#   'gender': 2,
#   'id': 496,
#   'job': 'Production Design',
#   'name': 'Rick Carter'},
#  {'credit_id': '54491c89c3a3680fb4001cf7',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 900,
#   'job': 'Sound Designer',
#   'name': 'Christopher Boyes'}]

# %%
def director(crew):
    crew_list = ast.literal_eval(crew)
    director = [x['name'] for x in crew_list if x['job'] == 'Director']
    return director
def producer(crew):
    crew_list = ast.literal_eval(crew)
    producers = [x['name'] for x in crew_list if x['job'] == 'Producer'][:3]
    return producers

# def producer(crew):
#     L=[ast.literal_eval(crew).index(x) for x in ast.literal_eval(crew) if  x['job']=='Producer']
#     producer=[]
#     for j in L[0:3]:
#         temp=ast.literal_eval(crew)[j]
#         if(temp['job']=='Producer'):
#             producer.append(temp['name'])
#     return producer

# df['Producer']=df['crew'].apply(producer)           ##################  TAKING LOT OF TIME TO RUN  ######################

# %%
director(df['crew'][1])
# Out:
# ['Gore Verbinski']

# %%
df['Producer']=df['crew'].apply(producer)

# %%
df['Director']=df['crew'].apply(director)

# %%
df1=df.drop(['crew'],axis=1)

# %%
df1['overview']=df1['overview'].apply(lambda x: x.split(','))

# %%
df2=df1.drop(['production_companies','production_countries','original_language','original_title','spoken_languages'],axis=1)

# %%
def norm(column):
    ans=column-column.mean()
    ans=ans/column.std()
    return round(ans,2)

# %%
df2['budget']=norm(df2['budget'])
df2['budget']=df2['budget'].apply(lambda x: [x])
df2['popularity']=norm(df2['popularity'])
df2['popularity']=df2['popularity'].apply(lambda x: [x])
df2['revenue']=norm(df2['revenue'])
df2['revenue']=df2['revenue'].apply(lambda x: [x])
df2['vote_average']=norm(df2['vote_average'])
df2['vote_average']=df2['vote_average'].apply(lambda x: [x])
df2['vote_count']=norm(df2['vote_count'])
df2['vote_count']=df2['vote_count'].apply(lambda x: [x])

# %%
df3=df2
df3['genres']=df2['genres'].apply(lambda x:[i.replace(" ","") for i in x])
df3['keywords']=df2['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
df3['cast']=df2['cast'].apply(lambda x:[i.replace(" ","") for i in x])
df3['Producer']=df2['Producer'].apply(lambda x:[i.replace(" ","") for i in x])
df3['Director']=df2['Director'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
df3['tags']=df3['genres']+df3['keywords']+df3['overview']+df3['cast']+df3['Producer']+df3['Director']+df3['budget']+df3['popularity']+df3['revenue']+df3['vote_average']+df3['vote_count']

# %%
df3['tags']=df3['tags'].apply(lambda x: " ".join(map(str, x)))

# %%
df3['tags'][0]
# Out:
# 'Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d In the 22nd century  a paraplegic Marine is dispatched to the moon Pandora on a unique mission  but becomes torn between following orders and protecting an alien civilization. SamWorthington ZoeSaldana SigourneyWeaver JamesCameron JonLandau JamesCameron 5.11 4.05 16.61 0.93 9.0'

# %%
df4=df3.drop(['budget','popularity','revenue','vote_average','vote_count','genres','keywords','overview','movie_id','cast','Producer','Director'],axis=1)

# %%
df4['tags'][0]
# Out:
# 'Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d In the 22nd century  a paraplegic Marine is dispatched to the moon Pandora on a unique mission  but becomes torn between following orders and protecting an alien civilization. SamWorthington ZoeSaldana SigourneyWeaver JamesCameron JonLandau JamesCameron 5.11 4.05 16.61 0.93 9.0'

# %%
df4['tags']=df4['tags'].apply(lambda x: x.lower())

# %%
df4['title']=df4['title'].apply(lambda x: x.lower())
df4
# Out:
#           id                                     title  \
# 0      19995                                    avatar
# 1        285  pirates of the caribbean: at world's end
# 2     206647                                   spectre
# 3      49026                     the dark knight rises
# 4      49529                               john carter
# ...      ...                                       ...
# 4795    9367                                      bang
# 4796   72766                                    primer
# 4797  231617                                    cavite
# 4798  126186                               el mariachi
# 4799   25975                                 newlyweds
#
#                                                    tags
# 0     action adventur fantasi sciencefict culturecla...
# 1     adventur fantasi action ocean drugabus exotici...
# 2     action adventur crime spi basedonnovel secreta...
# 3     action crime drama thriller dccomic crimefight...
# 4     action adventur sciencefict basedonnovel mar m...
# ...                                                 ...
# 4795  action crime thriller unitedstates–mexicobarri...
# 4796  comedi romanc a newlyw couple' honeymoon is up...
# 4797  comedi drama romanc tvmovi date loveatfirstsig...
# 4798  when ambiti new york attorney sam is sent to s...
# 4799  documentari obsess camcord crush dreamgirl eve...
#
# [4800 rows x 3 columns]

# %%
df4['tags'][0]
# Out:
# 'action adventure fantasy sciencefiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d in the 22nd century  a paraplegic marine is dispatched to the moon pandora on a unique mission  but becomes torn between following orders and protecting an alien civilization. samworthington zoesaldana sigourneyweaver jamescameron jonlandau jamescameron 5.11 4.05 16.61 0.93 9.0'

# %%
df4['tags']=df4['tags'].apply(stem)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
mat=cv.fit_transform(df4['tags']).toarray()

# %%
mat.shape
# Out:
# (4800, 5000)

# %%
cv.get_feature_names_out()
# Out:
# array(['000', '007', '01', ..., 'zone', 'zoo', 'zooeydeschanel'],
#       dtype=object)

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()                                ##### convert loved, loving to love ,, danceing dance to danc

# %%
def stem(text):
    l=[]
    for i in text.split():
        l.append(ps.stem(i))
    l=" ".join(l)
    return l

# %% [markdown]
# stem('ashutosh ashuto ashutoshing')

# %%
df4['tags'][0]
# Out:
# 'action adventur fantasi sciencefict cultureclash futur spacewar spacecoloni societi spacetravel futurist romanc space alien tribe alienplanet cgi marin soldier battl loveaffair antiwar powerrel mindandsoul 3d in the 22nd centuri a parapleg marin is dispatch to the moon pandora on a uniqu mission but becom torn between follow order and protect an alien civilization. samworthington zoesaldana sigourneyweav jamescameron jonlandau jamescameron 5.11 4.05 16.61 0.93 9.0'

# %%
# finding cosine distance b/w movie vectors
# cosine similarity = 1/ cosine distance =1/ angle bw vectors

# %%
from sklearn.metrics.pairwise  import cosine_similarity

# %%
similarity=cosine_similarity(mat)

# %%
similarity.shape
# Out:
# (4800, 4800)

# %%
similarity[0]
# Out:
# array([1.        , 0.07063224, 0.07537784, ..., 0.03959038, 0.02051525,
#        0.        ])

# %%
sorted(similarity[0],reverse=True)[0:10]  ### index positions lost after sorting
# Out:
# [0.9999999999999999,
#  0.2771609312622936,
#  0.24972268432951011,
#  0.2461829819586655,
#  0.23354968324845687,
#  0.22438727760202976,
#  0.2201927530252721,
#  0.220043114711676,
#  0.21452908258025832,
#  0.21320071635561041]

# %%
### we do mapping here
# sorted(list(enumerate(similarity[0])), reverse=True)[0:10] do sorting by index 0 enumerator


sorted(list(enumerate(similarity[0])), reverse=True, key=lambda x: x[1])[0:10]
# Out:
# [(0, 0.9999999999999999),
#  (2403, 0.2771609312622936),
#  (1213, 0.24972268432951011),
#  (2994, 0.2461829819586655),
#  (582, 0.23354968324845687),
#  (507, 0.22438727760202976),
#  (1191, 0.2201927530252721),
#  (3723, 0.220043114711676),
#  (539, 0.21452908258025832),
#  (1198, 0.21320071635561041)]

# %%
def recommend(movie):
    try:
        indx=df4[df4['title']==movie.lower()].index[0]
        movie_list=sorted(list(enumerate(similarity[indx])), reverse=True, key=lambda x: x[1])[1:6]
        for i,_ in movie_list:
            print(df4.iloc[i]['title'])
    except IndexError:
        print('Movie Not Found !!!')

# %%
recommend('Inception')
# Out:
# 12 rounds
# the iceman
# pontypool
# a hard day's night
# ghost dog: the way of the samurai

# %%
import numpy as np
np.save('similarity.npy', similarity)
